# %%
#https://dev.socrata.com/foundry/data.cdc.gov/8xkx-amqh - Data Source API Documentation
#https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-County/8xkx-amqh - CDC documentation

import pandas as pd
import sodapy

client = sodapy.Socrata("data.cdc.gov", None)
results = client.get("8xkx-amqh", limit=20)
test = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
test.head(3)
# Out:
#                       date   fips mmwr_week    recip_county recip_state  \
# 0  2021-12-13T00:00:00.000  12071        50      Lee County          FL
# 1  2021-12-13T00:00:00.000  21155        50   Marion County          KY
# 2  2021-12-13T00:00:00.000    UNK        50  Unknown County          KY
#
#   series_complete_pop_pct series_complete_yes series_complete_12plus  \
# 0                    58.4              450202                 448034
# 1                    46.9                9040                   8951
# 2                       0              143323                 142403
#
#   series_complete_12pluspop series_complete_18plus  ... svi_ctgy  \
# 0                      65.5                 429908  ...        C
# 1                      55.2                   8457  ...        D
# 2                       0.0                 136422  ...      NaN
#
#   series_complete_pop_pct_svi series_complete_12pluspop_pct_svi  \
# 0                          12                                12
# ...
